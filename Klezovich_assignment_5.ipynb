# %% [markdown]
# # Assignment 5
#
# Explore embeddings and CNN
#
# Using tweeter dataset ( https://www.kaggle.com/utathya/sentiment-analysis-of-imdb-reviews/data) and already existing splitting on train/test sets, develop a model for sentiment analysis.
# Your quality metric is crossentropy (`sklearn.metrics.log_loss`, `torch.nn.CrossEntropy`)
#
# Your model should be based on CNN and written in pytorch `torch.nn.Conv1d`.
#
# Explore 3 ways, which of them has better perfomance on test set?:
# 1. Using pretrained word embeddings with frozen weights. `torch.nn.Embedding.from_pretrained(embed_matrix, frozen=True)`.
# You can download any pretrained embeddings you like.
# 2. Train embeddings yourself, initializing from pretrained weights. `torch.nn.Embedding.from_pretrained(embed_matrix, frozen=False)`
# 3. Train embeddings yourself with random initialization `torch.nn.init.uniform_(nn.Embeddings.weights)`
#
# Experiment with model arhitecture (as bonus):
# 1. activation functions RELU, ELU, etc `torch.nn.functional.relu, torch.nn.functional.elu`
# 1. Stack layers
# 1. max or average pooling (`torch.nn.functional.max_pool1d, torch.nn.functional.avg_pool1d`)
# 1. Dropout
#
#
# Other requirements:
# 1. Your training routine should use any learning scheduler (torch.nn.optim.lr_scheduler).
# Plot current learning rate against number of epochs, e.g. `tt.optim.Adam.param_groups[0]['lr']`.
#
# 1. Your training routine should use early stopping on validation dataset
# Use hold out validation scheme in your experiments.
#
# 1. You should use torchtext for parsing
#
# **Note**:
# This assignment has no baseline. Instead, **validation curves** for explored architectures are expected.
# Validation curve is plot of model test score against model hyperparameter value.
# example (https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html) .
# Though, using `sklearn.model_selection.validation_curve` is not necessary.

# %%
import pandas as pd
import numpy as np
from sklearn.externals import joblib
import nltk
import gensim
import spacy

from sklearn import metrics

import torch as tt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchtext.data import Field, LabelField, BucketIterator, TabularDataset, Iterator



SEED = 42
np.random.seed(SEED)
# Out:
# d:\python371\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import spacy


spacy_en = spacy.load('en')

def tokenizer(text): # create a tokenizer function
    return [tok.text for tok in spacy_en.tokenizer(text) if tok.text.isalpha()]

# %%
classes={
    'negative':0,
    'neutral':1,
    'positive':2
}

TEXT = Field(include_lengths=True, batch_first=True, 
             tokenize=tokenizer,
             eos_token='<eos>',
             lower=True,
             stop_words=nltk.corpus.stopwords.words('english'))
LABEL = LabelField(dtype=tt.int64, use_vocab=True, preprocessing=lambda x: classes[x])

dataset = TabularDataset('Tweets.csv', format='csv', 
                         fields=[(None, None),('label', LABEL), (None, None),(None, None),('text', TEXT)], 
                         skip_header=True)

# %%
# TEXT.build_vocab(dataset, min_freq=10, vectors="glove.6B.100d")
TEXT.build_vocab(dataset, min_freq=5)
len(TEXT.vocab.itos)
# Out:
# 2748

# %%
TEXT.vocab.itos[:10]
# Out:
# ['<unk>',
#  '<pad>',
#  '<eos>',
#  'flight',
#  'get',
#  'thanks',
#  'cancelled',
#  'service',
#  'help',
#  'time']

# %%
LABEL.build_vocab(dataset)

# %%
train, test = dataset.split(0.7, stratified=True)
train, valid = train.split(0.7, stratified=True)

# %%
model0 = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True, encoding='utf-8', unicode_errors='ignore')

# %%
embed_matrix = tt.FloatTensor(model0.syn0)
# Out:
# d:\python371\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
class MyModel(nn.Module):
    
    def __init__(self, vocab_size, embed_size, hidden_size, kernels):
        super(MyModel, self).__init__()
        # self.embedding = nn.Embedding(vocab_size, embed_size)
        self.embedding = nn.Embedding.from_pretrained(embed_matrix, freeze=True)
        
        self.convs = nn.ModuleList([nn.Conv1d(embed_size, hidden_size, k, padding=5) for k in kernels])
        
        self.fc = nn.Linear(hidden_size * len(kernels), 3)
        
    def forward(self, x, x_lengths):
        
        x = self.embedding(x)
        x = x.transpose(1,2)
        
        concatenated = []
        for conv in self.convs:
            z = conv(x)
            z = F.avg_pool1d(z, kernel_size=z.size(2))
            z = z.squeeze(2)
            concatenated.append(z)
            
        x = tt.cat(concatenated, 1)
        x = self.fc(x)
        return x
    
    def predict(self, X):
        xt = tt.from_numpy(X.toarray())
        pred = model.forward(xt)
        pred = tt.softmax(pred, dim=-1)
        pred = pred.detach().numpy()
        predicted_y = np.argmax(pred, axis=1)
        return predicted_y

# %%
tt.cuda.empty_cache()

batch_size = 32

model = MyModel(len(TEXT.vocab.itos),
                embed_size=300,
                hidden_size=128,
                kernels=[2,3,4,5]
               )

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train, valid, test),
    batch_sizes=(batch_size, batch_size, batch_size),
    shuffle=True,
    sort_key=lambda x: len(x.text),
#     sort_within_batch=True,
)

optimizer = optim.Adam(model.parameters())
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, verbose=True, cooldown=5)
criterion = nn.CrossEntropyLoss()

# %%
def evaluate(model, iterator, criterion):
    epoch_loss = 0
    model.eval()
    with tt.no_grad():
        for batch in iterator:

            predictions = model(batch.text).squeeze(1)
            
            loss = criterion(predictions, batch.label)
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
len(train_iterator)
# Out:
# 225

# %%
# train ...
n_epochs = 100
min_loss = 300
early = 0
for epoch in range(n_epochs):  
    loss_t = 0
    loss_v = 0
    for batch in train_iterator:
        optimizer.zero_grad()
        pred = model.forward(batch.text[0], None)
        loss = criterion(pred, batch.label)
        loss.backward()
        
        optimizer.step()
        loss_t += loss.data.detach().item()
        
    loss_t /= len(train_iterator)
        
    # early stopping
    if loss_t < min_loss:
        min_loss = loss_t
        early = 0
    else:
        early += 1
    if early > 10:
        break
        
    for batch in valid_iterator:
        pred_valid = model.forward(batch.text[0], None)
        loss_v += criterion(pred_valid, batch.label)
    
    print('Epoch [%d/%d], Loss: %.4f'
          %(epoch+1, n_epochs, loss_t))
# Out:
# Epoch [1/100], Loss: 0.8452
# Epoch [2/100], Loss: 0.7838

# %%
model.predict([x.text for x in test])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-104087395806> in <module>
# ----> 1 model.predict([x.text for x in test])
#
# NameError: name 'model' is not defined

# %%
tt.nn.CrossEntropy([x.label for x in test.examples], model.predict([x.text for x in test]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-52e2d4bec9fa> in <module>
# ----> 1 tt.nn.CrossEntropy([x.label for x in test.examples], model.predict([x.text for x in test]))
#
# AttributeError: module 'torch.nn' has no attribute 'CrossEntropy'

# %%
[x.text for x in test]
# Out:
# [['pm', 'still', 'bag'],
#  ['pls',
#   'find',
#   'bag',
#   'need',
#   'get',
#   'home',
#   'frustrating',
#   'hope',
#   'bag',
#   'somewhere',
#   'leaving',
#   'jfk',
#   'luggage'],
#  ['ca', 'speak', 'customer', 'service', 'still', 'hold', 'guys'],
#  ['looks',
#   'like',
#   'already',
#   'delayed',
#   'miss',
#   'connecting',
#   'flight',
#   'philadelphia',
#   'un',
#   'delay',
#   'flights'],
#  ['plane',
#   'land',
#   'identical',
#   'worse',
#   'conditions',
#   'grk',
#   'according',
#   'metars'],
#  ['omg',
#   'bag',
#   'enough',
#   'shenanigans',
#   'already',
#   'getting',
#   'real',
#   'old',
#   'real',
#   'quick'],
#  ['rebooked',
#   'split',
#   'take',
#   'different',
#   'flights',
#   'pilot',
#   'ran',
#   'hours',
#   'frustrating'],
#  ['completely',
#   'let',
#   'tonight',
#   'gate',
#   'agents',
#   'ambivalence',
#   'much',
#   'sad',
#   'amp'],
#  ['found',
#   'midnight',
#   'last',
#   'night',
#   'would',
#   'think',
#   'agent',
#   'lax',
#   'could',
#   'relayed',
#   'info',
#   'bag',
#   'flt'],
#  ['stunned',
#   'bags',
#   'hartford',
#   'ord',
#   'ground',
#   'crew',
#   'hour',
#   'move',
#   'bags',
#   'yards'],
#  ['vx',
#   'use',
#   'lga',
#   'slots',
#   'instead',
#   'today',
#   'adding',
#   'aus',
#   'makes',
#   'less',
#   'likely'],
#  ['get',
#   'kind',
#   'update',
#   'delayed',
#   'flight',
#   'boston',
#   'houston',
#   'really',
#   'need',
#   'back',
#   'home',
#   'tonight'],
#  ['bag', 'sos', 'itis', 'lost', 'hours', 'poorcustumerservice'],
#  ['flight',
#   'nyc',
#   'buenos',
#   'aires',
#   'delay',
#   'since',
#   'yesterday',
#   'going',
#   'take',
#   'give',
#   'us',
#   'answers'],
#  ['patient', 'originally'],
#  ['shows',
#   'one',
#   'flight',
#   'one',
#   'way',
#   'try',
#   'go',
#   'home',
#   'page',
#   'book',
#   'roundtrip',
#   'nothing',
#   'available'],
#  ['sure',
#   'talking',
#   'going',
#   'nonstop',
#   'flights',
#   'sna',
#   'sfo',
#   'sfo',
#   'ewr'],
#  ['unhappy',
#   'new',
#   'mileage',
#   'rules',
#   'main',
#   'reason',
#   'keep',
#   'flying',
#   'united',
#   'take',
#   'business',
#   'elsewhere'],
#  ['let',
#   'employees',
#   'treat',
#   'loyal',
#   'customers',
#   'attackingbabymomma',
#   'crazinessintherockies'],
#  ['never', 'treated', 'badly'],
#  ['contact', 'stuff', 'bag', 'legally', 'blind', 'messed'],
#  ['hold',
#   'min',
#   'flight',
#   'got',
#   'cancelled',
#   'flightled',
#   'rescheduled',
#   'monday',
#   'unacceptable'],
#  ['hey',
#   'jetblue',
#   'stranded',
#   'entire',
#   'plane',
#   'supposed',
#   'go',
#   'jfk',
#   'getting',
#   'restless',
#   'need',
#   'better',
#   'communication'],
#  ['scheduling',
#   'skills',
#   'failed',
#   'delay',
#   'went',
#   'four',
#   'hours',
#   'nearly',
#   'six',
#   'tell',
#   'snowbound',
#   'pbi'],
#  ['minutes'],
#  ['yet', 'waiting', 'connected', 'agent'],
#  ['still',
#   'know',
#   'skis',
#   'get',
#   'call',
#   'back',
#   'bag',
#   'svc',
#   'airport',
#   'left',
#   'several',
#   'msgs'],
#  ['hour',
#   'flight',
#   'fll',
#   'ewr',
#   'waiting',
#   'hour',
#   'plus',
#   'bags',
#   'sign',
#   'yet',
#   'gives'],
#  ['two',
#   'dozen',
#   'back',
#   'line',
#   'see',
#   'single',
#   'csr',
#   'reflight',
#   'booking',
#   'problems',
#   'final',
#   'leg',
#   'kiosks',
#   'fritz'],
#  ['forget',
#   'reservations',
#   'thank',
#   'great',
#   'leadership',
#   'company',
#   'cancelled',
#   'flighted',
#   'flight',
#   'thank'],
#  ['yea',
#   'hoping',
#   'avoid',
#   'ticket',
#   'difference',
#   'amount',
#   'birthday',
#   'courtesy',
#   'flysouthwest',
#   'lovesouthwest',
#   'mybday'],
#  ['customer', 'service', 'solution', 'might', 'miss', 'show'],
#  ['appreciate',
#   'actually',
#   'responded',
#   'travel',
#   'way',
#   'much',
#   'tell',
#   'coffee',
#   'basic',
#   'option'],
#  ['oh',
#   'sure',
#   'planned',
#   'occurs',
#   'absolutely',
#   'consistently',
#   'usually',
#   'yyj',
#   'flight',
#   'cancelled',
#   'flightled',
#   'daily'],
#  ['airlines', 'change', 'ticket', 'prices', 'middle', 'day', 'annoyed'],
#  ['minute',
#   'wait',
#   'times',
#   'help',
#   'cancelled',
#   'flightled',
#   'flight',
#   'help',
#   'guy'],
#  ['looks',
#   'like',
#   'running',
#   'day',
#   'still',
#   'ca',
#   'get',
#   'phone',
#   'follow',
#   'dm',
#   'info'],
#  ['amount',
#   'money',
#   'spent',
#   'hotels',
#   'week',
#   'bc',
#   'flight',
#   'cancelled',
#   'flightlation',
#   'another',
#   'flight',
#   'make',
#   'money',
#   'lost'],
#  ['despite',
#   'fact',
#   'see',
#   'answering',
#   'people',
#   'twitter',
#   'mundane',
#   'qs',
#   'refuse',
#   'answer'],
#  ['still', 'waiting', 'dm', 'response', 'sloooowresponses'],
#  ['nope',
#   'could',
#   'make',
#   'changes',
#   'online',
#   'mins',
#   'hold',
#   'time',
#   'dealing',
#   'rude',
#   'rep',
#   'hour',
#   'window',
#   'closed'],
#  ['ticket',
#   'poor',
#   'gesture',
#   'goodwill',
#   'missed',
#   'trip',
#   'top',
#   'status',
#   'flyer',
#   'may',
#   'next',
#   'time',
#   'lhr',
#   'ord'],
#  ['yes',
#   'able',
#   'get',
#   'push',
#   'notification',
#   'via',
#   'app',
#   'logged',
#   'trip',
#   'email',
#   'text'],
#  ['need',
#   'know',
#   'status',
#   'cancelled',
#   'flightled',
#   'instead',
#   'delaying',
#   'flight'],
#  ['rebooked',
#   'hours',
#   'original',
#   'flight',
#   'say',
#   'handling',
#   'situation',
#   'bad',
#   'would',
#   'understatement'],
#  ['come', 'reopen', 'ord', 'clear', 'growing', 'dc', 'backlog'],
#  ['ca',
#   'beat',
#   'storm',
#   'town',
#   'wait',
#   'issue',
#   'policy',
#   'late',
#   'flight',
#   'nws',
#   'issued',
#   'storm',
#   'warning',
#   'already'],
#  ['guy',
#   'u',
#   'served',
#   'drinks',
#   'til',
#   'needed',
#   'awheelchair',
#   'get',
#   'plane',
#   'important',
#   'assaulted',
#   'women'],
#  ['worst',
#   'flights',
#   'ever',
#   'ground',
#   'crew',
#   'ignored',
#   'plane',
#   'made',
#   'miss',
#   'flight',
#   'cover',
#   'cost',
#   'hotel',
#   'den'],
#  ['app',
#   'needs',
#   'updating',
#   'says',
#   'flight',
#   'time',
#   'well',
#   'past',
#   'boarding',
#   'time',
#   'delay'],
#  ['rt',
#   'paid',
#   'early',
#   'bird',
#   'boarding',
#   'got',
#   'said',
#   'lady',
#   'well',
#   'system',
#   'dead',
#   'understand'],
#  ['appreciate',
#   'system',
#   'busy',
#   'call',
#   'automated',
#   'system',
#   'hang',
#   'helpful'],
#  ['could',
#   'wanted',
#   'call',
#   'would',
#   'use',
#   'internet',
#   'make',
#   'reservation',
#   'site',
#   'wo',
#   'work',
#   'chrome',
#   'several',
#   'computers'],
#  ['see',
#   'tweeting',
#   'little',
#   'min',
#   'ago',
#   'ignoring',
#   'cs',
#   'request',
#   'cantlogoutofunitedwifi'],
#  ['also',
#   'get',
#   'excited',
#   'going',
#   'unable',
#   'contact',
#   'destination',
#   'get',
#   'talk'],
#  ['upset',
#   'customer',
#   'service',
#   'simple',
#   'question',
#   'phone',
#   'system',
#   'disconnected',
#   'day',
#   'today',
#   'yesterday'],
#  ['huh',
#   'sent',
#   'crash',
#   'reports',
#   'feb',
#   'alone',
#   'one',
#   'day',
#   'app',
#   'consistently',
#   'crashes'],
#  ['row',
#   'flight',
#   'today',
#   'looking',
#   'specifics',
#   'run',
#   'home',
#   'depot',
#   'need'],
#  ['lie'],
#  ['near', 'gate', 'mean', 'sitting', 'plane', 'almost', 'hours', 'yeah'],
#  ['itinerary',
#   'ewr',
#   'dallas',
#   'la',
#   'cancelled',
#   'flightled',
#   'flight',
#   'money',
#   'find',
#   'way',
#   'get',
#   'ewr'],
#  ['guess',
#   'able',
#   'anything',
#   'improve',
#   'time',
#   'looks',
#   'even',
#   'late',
#   'flightr',
#   'going',
#   'zombie',
#   'tomorrow'],
#  ['maintenance',
#   'issues',
#   'flight',
#   'issues',
#   'passengers',
#   'miss',
#   'connections',
#   'needing',
#   'get'],
#  ['great',
#   'customer',
#   'service',
#   'come',
#   'know',
#   'expect',
#   'luv',
#   'dropped',
#   'eb',
#   'check',
#   'help',
#   'sight'],
#  ['thanks',
#   'answer',
#   'question',
#   'want',
#   'make',
#   'reservation',
#   'phone',
#   'perth',
#   'hold',
#   'family'],
#  ['service', 'agents', 'mco', 'great', 'enough', 'working', 'right'],
#  ['friend', 'lost', 'luggage', 'flight'],
#  ['delayed',
#   'san',
#   'pedro',
#   'belize',
#   'scheduled',
#   'fly',
#   'pm',
#   'belize',
#   'city',
#   'houston',
#   'wait',
#   'please'],
#  ['bought',
#   'tickets',
#   'months',
#   'ago',
#   'seats',
#   'together',
#   'changed',
#   'flight',
#   'kids',
#   'seats',
#   'scattered',
#   'plane'],
#  ['online',
#   'clearly',
#   'states',
#   'says',
#   'call',
#   'res',
#   'already',
#   'explained'],
#  ['thanks', 'response', 'flight', 'time', 'passed', 'rebooked'],
#  ['wifi', 'stinks', 'mad', 'would', 'hate', 'got', 'money', 'refunded'],
#  ['flight',
#   'cancelled',
#   'flighted',
#   'time',
#   'ca',
#   'reach',
#   'agent',
#   'reschedule',
#   'call'],
#  ['love',
#   'airline',
#   'hate',
#   'website',
#   'tried',
#   'book',
#   'tickets',
#   'w',
#   'miles',
#   'w',
#   'absolute',
#   'joke',
#   'needs',
#   'lot',
#   'work'],
#  ['sounds',
#   'like',
#   'planned',
#   'better',
#   'since',
#   'weather',
#   'surprise',
#   'completely',
#   'unacceptable',
#   'wait',
#   'times'],
#  ['update', 'flight', 'would', 'great'],
#  ['utterly',
#   'frustrated',
#   'hours',
#   'hold',
#   'call',
#   'disconnected',
#   'need',
#   'amend',
#   'flight',
#   'booking',
#   'problems',
#   'help',
#   'ow',
#   'emerald'],
#  ['appreciate',
#   'getting',
#   'put',
#   'hold',
#   'getting',
#   'hung',
#   'requesting',
#   'help',
#   'big',
#   'group',
#   'try',
#   'delta'],
#  ['everything', 'return', 'jet', 'go', 'miami'],
#  ['still', 'trying', 'get', 'things', 'worked', 'yet', 'respond', 'back'],
#  ['disgusted',
#   'poor',
#   'customer',
#   'service',
#   'u',
#   'wrongfully',
#   'remove',
#   'gt',
#   'miles',
#   'dividend',
#   'miles',
#   'live',
#   'person'],
#  ['long',
#   'someone',
#   'remembers',
#   'put',
#   'plane',
#   'right',
#   'really',
#   'lame',
#   'excuse',
#   'geez',
#   'much',
#   'better',
#   'coffeeneeded'],
#  ['almost',
#   'hours',
#   'heard',
#   'nothing',
#   'yet',
#   'reservations',
#   'team',
#   'supposed'],
#  ['airline',
#   'rated',
#   'worst',
#   'america',
#   'got',
#   'work',
#   'cut',
#   'bc',
#   'treat',
#   'customers',
#   'like',
#   'garbage'],
#  ['seriously', 'though', 'direct', 'flights', 'sfo', 'fll', 'may'],
#  ['call', 'wait', 'times', 'minutes', 'airport', 'wait', 'times', 'longer'],
#  ['guys',
#   'let',
#   'four',
#   'hour',
#   'delay',
#   'honolulu',
#   'houston',
#   'thanks',
#   'train',
#   'wreck',
#   'issues',
#   'coming'],
#  ['stingiest',
#   'airline',
#   'nobody',
#   'model',
#   'ptfo',
#   'cheap',
#   'bastards',
#   'stingy'],
#  ['fights', 'air'],
#  ['take',
#   'one',
#   'reps',
#   'different',
#   'gate',
#   'rude',
#   'asked',
#   'assistance',
#   'thanks',
#   'though'],
#  ['wait', 'times', 'customer', 'service', 'line', 'tried', 'fri', 'min'],
#  ['getting', 'business', 'unfriendlyskies', 'unbelievable'],
#  ['whole',
#   'plane',
#   'old',
#   'plane',
#   'seats',
#   'leather',
#   'coming',
#   'apart',
#   'ay',
#   'seams'],
#  ['never', 'choose', 'getmeoffthisbird'],
#  ['think', 'board', 'back', 'plane', 'whatstheholdup', 'chitocle'],
#  ['hey', 'dm', 'working', 'ua'],
#  ['changing',
#   'flights',
#   'explanations',
#   'still',
#   'confirmation',
#   'disappointed',
#   'service'],
#  ['hold', 'flight', 'boarding', 'taken', 'place', 'minutes', 'ago'],
#  ['need', 'accommodating', 'loyal', 'customers', 'happy'],
#  ['submitted',
#   'complaint',
#   'via',
#   'link',
#   'amp',
#   'followed',
#   'never',
#   'heard',
#   'back',
#   'badcustomerservice'],
#  ['ridiculous',
#   'delayed',
#   'hours',
#   'counting',
#   'booked',
#   'diff',
#   'airline',
#   'takes',
#   'seriously',
#   'unitedsucks'],
#  ['yes',
#   'filed',
#   'report',
#   'atlanta',
#   'bags',
#   'charlotte',
#   'nc',
#   'hours',
#   'late',
#   'flightr',
#   'still',
#   'ca',
#   'find',
#   'luggage'],
#  ['also', 'mosaic', 'customer', 'fly', 'jet', 'blue', 'alot'],
#  ['pilot',
#   'admitted',
#   'us',
#   'delay',
#   'entirely',
#   'aa',
#   'incompetence',
#   'poor',
#   'equip',
#   'checks'],
#  ['pathetic',
#   'customer',
#   'service',
#   'bag',
#   'tags',
#   'barcodes',
#   'computers',
#   'response',
#   'yet',
#   'located'],
#  ['yes',
#   'last',
#   'month',
#   'boston',
#   'got',
#   'first',
#   'big',
#   'snow',
#   'storm',
#   'flight',
#   'cancelled',
#   'flightled'],
#  ['really',
#   'clean',
#   'food',
#   'coffee',
#   'stains',
#   'area',
#   'around',
#   'seats',
#   'new',
#   'passengers',
#   'come',
#   'aboard',
#   'gross'],
#  ['since',
#   'care',
#   'happens',
#   'passengers',
#   'planes',
#   'contacting',
#   'police',
#   'dept'],
#  ['ah',
#   'yes',
#   'put',
#   'bags',
#   'floor',
#   'instead',
#   'overhead',
#   'bin',
#   'one',
#   'trips',
#   'safetyfirst',
#   'sarcasm'],
#  ['slept',
#   'miami',
#   'airport',
#   'due',
#   'mechanical',
#   'issues',
#   'given',
#   'bonus',
#   'miles',
#   'try',
#   'make',
#   'right',
#   'slapintheface'],
#  ['arriving',
#   'minutes',
#   'early',
#   'nice',
#   'equipment',
#   'ready',
#   'waiting',
#   'minutes',
#   'luggage',
#   'far',
#   'time',
#   'gains',
#   'wiped'],
#  ['load',
#   'us',
#   'flying',
#   'sardine',
#   'knew',
#   'pilots',
#   'hours',
#   'late',
#   'flight',
#   'incompetent',
#   'beyond',
#   'belief'],
#  ['told', 'call', 'back', 'late', 'flightr'],
#  ['still', 'stucked', 'airport', 'aadelay'],
#  ['got',
#   'email',
#   'itinerary',
#   'change',
#   'ca',
#   'seem',
#   'get',
#   'anyone',
#   'phone',
#   'new',
#   'flight',
#   'time',
#   'work',
#   'help'],
#  ['booked', 'different', 'ones', 'past', 'days'],
#  ['love',
#   'taking',
#   'money',
#   'taking',
#   'halfway',
#   'home',
#   'sorry',
#   'late',
#   'flight'],
#  ['kidding',
#   'needed',
#   'help',
#   'yesterday',
#   'landed',
#   'waiting',
#   'connection',
#   'never',
#   'fly',
#   'southwest'],
#  ['forced',
#   'check',
#   'rollaboard',
#   'ua',
#   'plenty',
#   'room',
#   'overhead',
#   'next',
#   'seat'],
#  ['feck',
#   'guys',
#   'stop',
#   'cancelled',
#   'flightling',
#   'flights',
#   'ewr',
#   'ric',
#   'weather',
#   'fine',
#   'locations'],
#  ['read',
#   'thread',
#   'booked',
#   'class',
#   'seated',
#   'even',
#   'though',
#   'united',
#   'twtr',
#   'account',
#   'confirmed',
#   'eco',
#   'premium'],
#  ['got', 'nothing', 'dissapointment'],
#  ['wait',
#   'hrs',
#   'cs',
#   'call',
#   'back',
#   'flt',
#   'cxld',
#   'protection',
#   'amp',
#   'hang',
#   'minute',
#   'answer',
#   'ring'],
#  ['flts',
#   'jfk',
#   'cancelled',
#   'flightled',
#   'thx',
#   'ur',
#   'agent',
#   'sfo',
#   'rebooked',
#   'ua',
#   'get',
#   'name',
#   'awesome',
#   'twitterhug',
#   'shesaidrun'],
#  ['trying', 'check', 'online', 'says', 'call', 'hold', 'hours'],
#  ['idea', 'upset', 'frustrated', 'right', 'sure', 'follow', 'never', 'flying'],
#  ['ordered',
#   'scotch',
#   'amp',
#   'water',
#   'f',
#   'asked',
#   'wanted',
#   'full',
#   'glass',
#   'half',
#   'yrs',
#   'old',
#   'first',
#   'time',
#   'ever',
#   'asked'],
#  ['outsourcing',
#   'ticket',
#   'gate',
#   'agents',
#   'mia',
#   'ill',
#   'advised',
#   'roc',
#   'service',
#   'went',
#   'downhill',
#   'keep',
#   'employees',
#   'fliers',
#   'first'],
#  ['unhelpful'],
#  ['still',
#   'waiting',
#   'captain',
#   'reports',
#   'called',
#   'times',
#   'get',
#   'ground',
#   'crew',
#   'still',
#   'sitting',
#   'runway',
#   'evenlate',
#   'flightr'],
#  ['thought',
#   'moving',
#   'lot',
#   'business',
#   'first',
#   'impressions',
#   'count',
#   'glad',
#   'miles',
#   'cash'],
#  ['missed',
#   'one',
#   'gate',
#   'marshall',
#   'us',
#   'rent',
#   'car',
#   'amp',
#   'drive',
#   'hrs',
#   'thanks'],
#  ['unfortunate',
#   'xmas',
#   'gift',
#   'looks',
#   'like',
#   'razor',
#   'ripped',
#   'right',
#   'front',
#   'pocket',
#   'picture'],
#  ['ca', 'check', 'online', 'flight', 'tomorrow'],
#  ['hoped',
#   'contacted',
#   'wks',
#   'ago',
#   'responded',
#   'still',
#   'issued',
#   'us',
#   'funds',
#   'frustrated'],
#  ['gave',
#   'one',
#   'try',
#   'figured',
#   'could',
#   'get',
#   'hr',
#   'flight',
#   'right',
#   'nope',
#   'delayed',
#   'hr',
#   'seems',
#   'every',
#   'time'],
#  ['mention', 'fact', 'flight', 'delayed', 'computers'],
#  ['people',
#   'exit',
#   'row',
#   'still',
#   'supposed',
#   'give',
#   'verbal',
#   'approvals',
#   'never',
#   'asked',
#   'flight'],
#  ['hold',
#   'approaching',
#   'hrs',
#   'issue',
#   'changed',
#   'ticket',
#   'online',
#   'frustrating'],
#  ['thanks',
#   'update',
#   'preciate',
#   'hope',
#   'gets',
#   'delayed',
#   'days',
#   'getting',
#   'back'],
#  ['plane',
#   'staying',
#   'overnight',
#   'next',
#   'airport',
#   'roc',
#   'u',
#   'make',
#   'min',
#   'air',
#   'instead',
#   'waiting',
#   'u',
#   'leave',
#   'early'],
#  ['sitting',
#   'tarmac',
#   'waiting',
#   'deplane',
#   'minutes',
#   'level',
#   'service',
#   'come',
#   'expect'],
#  ['big', 'board', 'says', 'leaving'],
#  ['apparently',
#   'substitute',
#   'pilots',
#   'flight',
#   'bos',
#   'fll',
#   'ca',
#   'found',
#   'info',
#   'avail',
#   'counter'],
#  ['freq',
#   'flyer',
#   'makes',
#   'sad',
#   'see',
#   'cust',
#   'needing',
#   'assistance',
#   'treated',
#   'poorly',
#   'servicefail'],
#  ['yet',
#   'supposed',
#   'get',
#   'early',
#   'evening',
#   'tonight',
#   'want',
#   'go',
#   'store',
#   'buy',
#   'new',
#   'necessities'],
#  ['hours', 'minutes', 'want', 'know', 'still', 'queue'],
#  ['stay', 'traveling', 'ans', 'sleeping', 'airports', 'floor'],
#  ['well',
#   'bar',
#   'set',
#   'low',
#   'guys',
#   'really',
#   'good',
#   'apology',
#   'game',
#   'change',
#   'u',
#   'guys',
#   'learn'],
#  ['overzealous',
#   'stewardess',
#   'prevented',
#   'us',
#   'bringing',
#   'car',
#   'seat',
#   'worstflight'],
#  ['bags',
#   'way',
#   'chicago',
#   'without',
#   'help',
#   'confirmed',
#   'flights',
#   'told',
#   'room',
#   'screwed'],
#  ['cabin',
#   'pressurization',
#   'issues',
#   'pretty',
#   'serious',
#   'flight',
#   'landed',
#   'washington',
#   'head',
#   'pounding'],
#  ['get', 'first', 'flight', 'day', 'ground', 'time', 'let', 'go'],
#  ['complete',
#   'cop',
#   'u',
#   'ask',
#   'issues',
#   'nothing',
#   'supposed',
#   'sort',
#   'situation'],
#  ['crazy', 'every', 'airline', 'flew', 'northeast', 'tonight', 'except'],
#  ['customer',
#   'service',
#   'stinks',
#   'trying',
#   'book',
#   'flight',
#   'hours',
#   'keep',
#   'getting',
#   'hung',
#   'usairwayssucks'],
#  ['hours',
#   'late',
#   'flightr',
#   'still',
#   'answers',
#   'stuck',
#   'houston',
#   'keep',
#   'getting',
#   'put',
#   'phantom',
#   'flights',
#   'never',
#   'apeared',
#   'badcustomerservice'],
#  ['app',
#   'repeatedly',
#   'crashed',
#   'failed',
#   'display',
#   'name',
#   'checking',
#   'unable',
#   'use',
#   'app'],
#  ['need', 'agents', 'check'],
#  ['even', 'leave', 'airport', 'sent', 'bags', 'philadelphia'],
#  ['bad',
#   'weather',
#   'understandable',
#   'pilot',
#   'said',
#   'people',
#   'called',
#   'zero',
#   'bags',
#   'plane'],
#  ['free', 'hotel', 'make', 'poor', 'customer', 'service', 'disregard'],
#  ['cancelled',
#   'flightled',
#   'flight',
#   'avail',
#   'flight',
#   'phl',
#   'today',
#   'u',
#   'said',
#   'sold',
#   'buy',
#   'ticket',
#   'u',
#   'need',
#   'refund'],
#  ['forced',
#   'sections',
#   'check',
#   'carry',
#   'would',
#   'packed',
#   'differently',
#   'check',
#   'bag',
#   'even',
#   'allow',
#   'pissed'],
#  ['delayed', 'missed', 'due', 'delay', 'new', 'flight', 'delayed'],
#  ['flt',
#   'cancelled',
#   'flightled',
#   'get',
#   'email',
#   'happened',
#   'courtesy',
#   'phn',
#   'call',
#   'book',
#   'diff',
#   'airline',
#   'amp',
#   'city'],
#  ['updates', 'take', 'hours', 'assistance', 'love'],
#  ['received',
#   'voucher',
#   'want',
#   'improve',
#   'relations',
#   'front',
#   'passengers'],
#  ['keep',
#   'getting',
#   'hung',
#   'please',
#   'respond',
#   'book',
#   'ticket',
#   'wo',
#   'able',
#   'buy',
#   'one',
#   'unless',
#   'speak',
#   'someone'],
#  ['cancelled',
#   'flight',
#   'tickets',
#   'thousands',
#   'people',
#   'like',
#   'exchange',
#   'rate',
#   'doublestandards'],
#  ['made', 'costa', 'rica', 'back', 'missing', 'already', 'pura', 'vida'],
#  ['luggage',
#   'delivery',
#   'really',
#   'told',
#   'midnight',
#   'multiple',
#   'times',
#   'lie',
#   'crazy',
#   'bad',
#   'business'],
#  ['cancelled',
#   'flight',
#   'flight',
#   'wait',
#   'line',
#   'get',
#   'rebooked',
#   'front',
#   'make',
#   'go',
#   'another',
#   'gate',
#   'lose',
#   'place'],
#  ['yeah', 'aware', 'hence', 'original', 'msg'],
#  ['another', 'fiasco', 'national', 'forever', 'jet', 'gate', 'flight', 'rdu'],
#  ['arriving',
#   'airport',
#   'hours',
#   'departure',
#   'time',
#   'still',
#   'missing',
#   'flight',
#   'bc',
#   'actually',
#   'electronic',
#   'ticket'],
#  ['still',
#   'left',
#   'maybe',
#   'time',
#   'suppose',
#   'fly',
#   'back',
#   'austin',
#   'tuesday',
#   'moved'],
#  ['taken',
#   'weeks',
#   'cust',
#   'care',
#   'respond',
#   'case',
#   'requesting',
#   'refund',
#   'wi',
#   'fi',
#   'working',
#   'get',
#   'update'],
#  ['frequent',
#   'traveler',
#   'never',
#   'treated',
#   'coldly',
#   'amp',
#   'airline',
#   'offer',
#   'nothing',
#   'flight',
#   'cancelled',
#   'flightled',
#   'nolove'],
#  ['know',
#   'policy',
#   'asking',
#   'little',
#   'kindness',
#   'due',
#   'extenuating',
#   'circumstances'],
#  ['well',
#   'going',
#   'help',
#   'hold',
#   'hrs',
#   'amp',
#   'client',
#   'wants',
#   'ff',
#   'nbr',
#   'record',
#   'elite',
#   'waa'],
#  ['minutes',
#   'holding',
#   'seriously',
#   'average',
#   'wait',
#   'time',
#   'minutes',
#   'maybe',
#   'maybe',
#   'understaffed'],
#  ['please',
#   'employee',
#   'called',
#   'times',
#   'flight',
#   'crew',
#   'finish',
#   'maintenance',
#   'us',
#   'depart'],
#  ['consider',
#   'mins',
#   'bags',
#   'sunday',
#   'night',
#   'fast',
#   'reconsider',
#   'think',
#   'means'],
#  ['submitted', 'customer', 'relations', 'form', 'await', 'response'],
#  ['extra',
#   'hours',
#   'travel',
#   'time',
#   'missed',
#   'vacation',
#   'time',
#   'guys',
#   'messing',
#   'professional',
#   'life'],
#  ['great', 'job', 'communicating', 'passengers', 'flight', 'exist', 'anymore'],
#  ['good',
#   'morning',
#   'tamara',
#   'try',
#   'get',
#   'comfortably',
#   'flight',
#   'soon',
#   'nocoatcloset'],
#  ['disappointing',
#   'experience',
#   'plane',
#   'mech',
#   'delay',
#   'next',
#   'one',
#   'wait',
#   'sincere',
#   'apology',
#   'told',
#   'complain',
#   'online'],
#  ['yes',
#   'pay',
#   'pocket',
#   'us',
#   'helping',
#   'loosing',
#   'first',
#   'class',
#   'ticket',
#   'coach',
#   'want',
#   'resolution',
#   'comp'],
#  ['would',
#   'hire',
#   'guy',
#   'care',
#   'safety',
#   'children',
#   'remotely',
#   'acceptable'],
#  ['months', 'straight', 'travel', 'ahead', 'time', 'find', 'new', 'airline'],
#  ['received',
#   'flights',
#   'united',
#   'truly',
#   'breaks',
#   'guitars',
#   'unitedbreaksguitars',
#   'wantmymoneyback'],
#  ['needs', 'hire', 'people'],
#  ['guys', 'suck', 'jfk', 'tonight', 'oh', 'morning'],
#  ['manage', 'itinerary', 'section', 'website', 'seems', 'broken'],
#  ['yr', 'team', 'hold', 'hour', 'unhelpful', 'pls', 'answer', 'question'],
#  ['internet',
#   'great',
#   'thing',
#   'emailing',
#   'executives',
#   'company',
#   'maybe',
#   'respond',
#   'timely',
#   'manner'],
#  ['worst',
#   'experience',
#   'ever',
#   'guys',
#   'see',
#   'blog',
#   'tomorrow',
#   'experience',
#   'maybe',
#   'help',
#   'make',
#   'better'],
#  ['first',
#   'class',
#   'snack',
#   'basket',
#   'catered',
#   'drinks',
#   'preflight',
#   'drink',
#   'coathanging',
#   'drink',
#   'service',
#   'min',
#   'take'],
#  ['flight',
#   'first',
#   'officer',
#   'even',
#   'airport',
#   'wow',
#   'unreal',
#   'staff',
#   'waited',
#   'boarded',
#   'announce',
#   'delayed'],
#  ['offered',
#   'flight',
#   'paid',
#   'changed',
#   'time',
#   'done',
#   'ruins',
#   'cruise',
#   'plans'],
#  ['waited', 'min', 'got', 'disconnect'],
#  ['big',
#   'surprise',
#   'nogate',
#   'waiting',
#   'plane',
#   'fucken',
#   'issues',
#   'everything',
#   'fly',
#   'fail',
#   'worstairlineever'],
#  ['swa',
#   'agent',
#   'jacquie',
#   'plitt',
#   'sna',
#   'rudely',
#   'tells',
#   'going',
#   'cabo',
#   'today',
#   'manana',
#   'back',
#   'phx',
#   'flew'],
#  ['mean',
#   'tsa',
#   'precheck',
#   'show',
#   'mobile',
#   'boarding',
#   'pass',
#   'ktn',
#   'linked',
#   'account'],
#  ['called',
#   'back',
#   'put',
#   'hold',
#   'midnight',
#   'literally',
#   'want',
#   'know',
#   'getting',
#   'home',
#   'getting',
#   'help'],
#  ['rebooked',
#   'disappointed',
#   'wait',
#   'whole',
#   'day',
#   'start',
#   'vacation',
#   'fares',
#   'united',
#   'top',
#   'notch',
#   'service'],
#  ['ca', 'american', 'airlines', 'suppose'],
#  ['still',
#   'need',
#   'help',
#   'hung',
#   'twice',
#   'customer',
#   'service',
#   'rep',
#   'said',
#   'way',
#   'help',
#   'gate',
#   'rep',
#   'phone',
#   'rep'],
#  ['flight', 'san', 'fransico', 'jfk', 'evacuated'],
#  ['mean', 'flights', 'going', 'buffalo', 'locations', 'care', 'safety'],
#  ['days',
#   'row',
#   'buying',
#   'suggest',
#   'review',
#   'policy',
#   'w',
#   'respect',
#   'unaccompanied',
#   'minors',
#   'seat',
#   'sun'],
#  ['wondering',
#   'reason',
#   'customer',
#   'service',
#   'busy',
#   'hold',
#   'past',
#   'days',
#   'many',
#   'hours',
#   'answer',
#   'help',
#   'plz'],
#  ['jal', 'cathay', 'pacific', 'ca', 'online'],
#  ['hold',
#   'mins',
#   'attempt',
#   'get',
#   'receipt',
#   'showing',
#   'change',
#   'fees',
#   'upcoming',
#   'flight',
#   'please',
#   'help'],
#  ['thanks',
#   'one',
#   'pilot',
#   'last',
#   'two',
#   'flights',
#   'stranding',
#   'houston',
#   'tonight',
#   'airlines',
#   'absolute',
#   'worst'],
#  ['going',
#   'website',
#   'flight',
#   'booking',
#   'problems',
#   'three',
#   'tickets',
#   'today',
#   'booted',
#   'system',
#   'umpteen',
#   'times'],
#  ['thank', 'paid', 'early', 'bird', 'sat', 'back'],
#  ['thank', 'hopefully', 'soon', 'supposed', 'leave'],
#  ['get', 'hold', 'called', 'twice', 'kicked', 'phonedied', 'alistpreferred'],
#  ['trying',
#   'book',
#   'flight',
#   'guys',
#   'website',
#   'wo',
#   'let',
#   'lose',
#   'business'],
#  ['made',
#   'fly',
#   'list',
#   'airlines',
#   'wait',
#   'connector',
#   'late',
#   'flight',
#   'stuck',
#   'iah'],
#  ['time', 'damn', 'thing', 'guy', 'winter', 'hat', 'frowny', 'face'],
#  ['going', 'baggage', 'claim'],
#  ['flight',
#   'gate',
#   'agent',
#   'tried',
#   'prevent',
#   'taking',
#   'onboard',
#   'bag',
#   'used',
#   'years',
#   'flight',
#   'crew',
#   'reasonable'],
#  ['compensate', 'us', 'new', 'clothes', 'bet', 'wo'],
#  ['told', 'case', 'weeks', 'still', 'resolved'],
#  ['rebooked',
#   'flight',
#   'questions',
#   'people',
#   'get',
#   'hotel',
#   'others',
#   'like'],
#  ['cool',
#   'canned',
#   'response',
#   'nah',
#   'think',
#   'keep',
#   'tweeting',
#   'everyone',
#   'mentions',
#   'aa',
#   'twitter',
#   'could',
#   'dm',
#   'though'],
#  ['premier',
#   'gold',
#   'desk',
#   'changes',
#   'flight',
#   'waives',
#   'fees',
#   'gives',
#   'wrong',
#   'flight',
#   'jana',
#   'acosta',
#   'salt',
#   'lake',
#   'refuses',
#   'service',
#   'angry'],
#  ['tried', 'already', 'waiting', 'list', 'call', 'back'],
#  ['last',
#   'times',
#   'checked',
#   'bags',
#   'severally',
#   'damaged',
#   'one',
#   'answers',
#   'baggage',
#   'call',
#   'line',
#   'status',
#   'chairmanlove'],
#  ['future',
#   'delay',
#   'causes',
#   'hour',
#   'wait',
#   'slept',
#   'night',
#   'airport',
#   'ensuring',
#   'seating',
#   'choice',
#   'replacement',
#   'flight',
#   'would',
#   'good'],
#  ['fly',
#   'back',
#   'omaha',
#   'grandmothers',
#   'funeral',
#   'cancelled',
#   'flight',
#   'return',
#   'flight',
#   'nt',
#   'bother',
#   'notify',
#   'thanks',
#   'lot'],
#  ['transportation',
#   'going',
#   'city',
#   'getting',
#   'ny',
#   'sometime',
#   'sorry',
#   'gon',
#   'na',
#   'cut'],
#  ['took',
#   'care',
#   'rent',
#   'car',
#   'drive',
#   'hours',
#   'retrieve',
#   'belongings',
#   'due',
#   'united',
#   'errors'],
#  ['flying',
#   'today',
#   'mty',
#   'mex',
#   'still',
#   'appear',
#   'cancelled',
#   'flight',
#   'talk',
#   'another',
#   'flight'],
#  ['received',
#   'one',
#   'previously',
#   'checked',
#   'odd',
#   'said',
#   'complaint',
#   'associated',
#   'e',
#   'mail'],
#  ['wrote',
#   'customer',
#   'support',
#   'monday',
#   'cancelled',
#   'flighted',
#   'flight',
#   'heard',
#   'back',
#   'idea',
#   'thanks'],
#  ['sorry',
#   'frustration',
#   'get',
#   'rebooked',
#   'rebooked',
#   'times',
#   'still',
#   'stuck',
#   'smh'],
#  ['even', 'bother', 'catering', 'dog', 'food', 'one', 'eat'],
#  ['first',
#   'class',
#   'joke',
#   'compared',
#   'others',
#   'flown',
#   'ask',
#   'extra',
#   'peanuts',
#   'allowed'],
#  ['received',
#   'email',
#   'requesting',
#   'call',
#   'res',
#   'keep',
#   'getting',
#   'kicked',
#   'phone',
#   'system',
#   'help'],
#  ['everyone',
#   'dickheads',
#   'aa',
#   'contacted',
#   'lost',
#   'checked',
#   'bag',
#   'amp',
#   'carryon',
#   'offer',
#   'pay'],
#  ['thanks',
#   'weather',
#   'understandable',
#   'every',
#   'single',
#   'domestic',
#   'flight',
#   'delayed',
#   'inbound',
#   'flights',
#   'crazy'],
#  ['problem',
#   'getting',
#   'fll',
#   'iah',
#   'sent',
#   'dm',
#   'making',
#   'connection',
#   'please',
#   'let',
#   'know'],
#  ['iad',
#   'buf',
#   'incredibly',
#   'loud',
#   'like',
#   'third',
#   'world',
#   'inner',
#   'city',
#   'metro',
#   'bus',
#   'lowstandards'],
#  ['becomes', 'get', 'money', 'passengers', 'strict', 'feedback', 'reward'],
#  ['spoke',
#   'soon',
#   'min',
#   'late',
#   'flightr',
#   'still',
#   'waiting',
#   'bags',
#   'load',
#   'sympathy',
#   'would',
#   'appreciated',
#   'least'],
#  ['estimate',
#   'holding',
#   'online',
#   'end',
#   'hour',
#   'forty',
#   'minutes',
#   'need',
#   'rebook'],
#  ['two',
#   'hours',
#   'plane',
#   'gate',
#   'undignified',
#   'behavior',
#   'apology',
#   'enough',
#   'freedrinkcoupons'],
#  ['ca', 'dm', 'following', 'rebooked', 'still', 'need', 'seats'],
#  ['literally',
#   'told',
#   'rather',
#   'empty',
#   'seat',
#   'mom',
#   'get',
#   'come',
#   'earlier',
#   'amp',
#   'take',
#   'appointment',
#   'wow'],
#  ['need',
#   'work',
#   'tomorrow',
#   'therefore',
#   'help',
#   'direct',
#   'message',
#   'faster',
#   'calling',
#   'number',
#   'backwards'],
#  ['inquire',
#   'nothing',
#   'pretend',
#   'interested',
#   'responded',
#   'dm',
#   'response',
#   'back'],
#  ['stop',
#   'pretending',
#   'care',
#   'welfare',
#   'daughter',
#   'united',
#   'airlines',
#   'opportunity',
#   'help',
#   'n',
#   'failed',
#   'united',
#   'airlines'],
#  ['person',
#   'talked',
#   'could',
#   'anything',
#   'normally',
#   'available',
#   'online',
#   'charge',
#   'part'],
#  ['hung'],
#  ['lady',
#   'one',
#   'phone',
#   'says',
#   'tel',
#   'aviv',
#   'tel',
#   'aviv',
#   'united',
#   'says',
#   'newark',
#   'one',
#   'knows',
#   'nothing'],
#  ['flight',
#   'cancelled',
#   'flightled',
#   'tried',
#   'get',
#   'refund',
#   'hold',
#   'get',
#   'flight',
#   'would',
#   'departed'],
#  ['even',
#   'mean',
#   'taking',
#   'letting',
#   'elite',
#   'customers',
#   'paid',
#   'seat',
#   'fill',
#   'seat',
#   'go',
#   'empty',
#   'anyway'],
#  ['need', 'get', 'ric', 'tonight', 'ewr'],
#  ['worst',
#   'service',
#   'ever',
#   'delayed',
#   'flights',
#   'hours',
#   'plus',
#   'missed',
#   'bag',
#   'employees',
#   'rude'],
#  ['much',
#   'longer',
#   'jfk',
#   'open',
#   'diabetic',
#   'need',
#   'sugar',
#   'plane',
#   'nothing'],
#  ['sitting', 'feet', 'open', 'gate'],
#  ['sitting', 'freezing', 'bus', 'nobody', 'plane'],
#  ['ivr', 'hung', 'high', 'call', 'volume', 'need', 'help', 'call'],
#  ['long',
#   'day',
#   'philly',
#   'flt',
#   'ord',
#   'cancelled',
#   'flighted',
#   'notice',
#   'message',
#   'email',
#   'nice',
#   'platinums'],
#  ['hold',
#   'w',
#   'customer',
#   'service',
#   'line',
#   'minutes',
#   'phone',
#   'agent',
#   'min',
#   'b',
#   'f',
#   'call',
#   'droped'],
#  ['compensates', 'delays', 'caused', 'fact', 'enough', 'flight', 'attendants'],
#  ['ur',
#   'service',
#   'shitty',
#   'pilot',
#   'never',
#   'showed',
#   'waited',
#   'hours',
#   'another',
#   'pilot',
#   'supposed',
#   'come',
#   'cancelled',
#   'flighted'],
#  ['airlines',
#   'delayed',
#   'flight',
#   'way',
#   'chicago',
#   'leaving',
#   'chicago',
#   'next',
#   'time'],
#  ['better', 'get', 'free', 'flight'],
#  ['told', 'wait', 'time', 'waiting', 'hours', 'hour', 'gone', 'ridiculous'],
#  ['obviously', 'one', 'knows', 'darn', 'thing', 'around', 'get', 'resolved'],
#  ['thanks',
#   'fill',
#   'form',
#   'soon',
#   'land',
#   'like',
#   'duped',
#   'hope',
#   'appreciate',
#   'feedback',
#   'amp',
#   'better'],
#  ['flight', 'came', 'late', 'flight', 'jetblue', 'employee', 'informed', 'us'],
#  ['response', 'days', 'thanks'],
#  ['yes',
#   'rebooked',
#   'next',
#   'day',
#   'weds',
#   'thanks',
#   'upset',
#   'lost',
#   'additional',
#   'work',
#   'days',
#   'paid',
#   'hotel',
#   'losing'],
#  ['days', 'one', 'flight', 'roundtrip'],
#  ['said',
#   'would',
#   'give',
#   'us',
#   'refund',
#   'days',
#   'late',
#   'flightr',
#   'refund'],
#  ['hey',
#   'yeah',
#   'last',
#   'time',
#   'got',
#   'phone',
#   'call',
#   'flight',
#   'cancelled',
#   'flightled',
#   'dca',
#   'bos'],
#  ['flown',
#   'us',
#   'airways',
#   'least',
#   'five',
#   'times',
#   'every',
#   'single',
#   'time',
#   'like',
#   'actions',
#   'speak',
#   'louder',
#   'words'],
#  ['mean',
#   'take',
#   'time',
#   'write',
#   'physical',
#   'letter',
#   'fraud',
#   'department',
#   'email',
#   'telephones',
#   'right'],
#  ['killing', 'always', 'delayed', 'sandiego', 'sf', 'ugh'],
#  ['united',
#   'flight',
#   'arrives',
#   'late',
#   'flight',
#   'told',
#   'book',
#   'connecting',
#   'united',
#   'flight',
#   'characterize',
#   'show'],
#  ['transferred', 'pleeeeeeeease', 'help'],
#  ['yes', 'response'],
#  ['slightly',
#   'better',
#   'crew',
#   'spent',
#   'long',
#   'time',
#   'searching',
#   'better',
#   'altitude',
#   'would',
#   'helped',
#   'let',
#   'pax',
#   'sharp',
#   'drops'],
#  ['dm', 'sent', 'lack', 'customer', 'service', 'getting', 'ridiculous'],
#  ['even', 'gluten', 'free', 'peanuts', 'whyyy'],
#  ['even',
#   'ask',
#   'dm',
#   'offer',
#   'help',
#   'ca',
#   'anything',
#   'terriblecustomerservice',
#   'unitedairlines'],
#  ['local',
#   'agent',
#   'person',
#   'answer',
#   'questions',
#   'phone',
#   'service',
#   'terrible'],
#  ['generic',
#   'form',
#   'tons',
#   'fields',
#   'asking',
#   'info',
#   'already',
#   'expected',
#   'premier',
#   'platinum',
#   'another',
#   'servicefail'],
#  ['morning', 'delayed', 'hours', 'get', 'newark', 'meeting'],
#  ['cost',
#   'change',
#   'city',
#   'origin',
#   'flight',
#   'costs',
#   'customerservicefail'],
#  ['let',
#   'passengers',
#   'board',
#   'issue',
#   'hour',
#   'amp',
#   'pilot',
#   'know',
#   'leave'],
#  ['extreme',
#   'inconvenience',
#   'make',
#   'ppl',
#   'check',
#   'bags',
#   'lot',
#   'overhead',
#   'space',
#   'left',
#   'lie',
#   'fault'],
#  ['sending', 'uvf', 'today', 'weekday', 'weekend'],
#  ['seriously', 'going'],
#  ['arriving',
#   'day',
#   'half',
#   'late',
#   'flightr',
#   'supposed',
#   'lesson',
#   'day',
#   'believe',
#   'verbal',
#   'written',
#   'confirmations',
#   'united'],
#  ['issue', 'persisting'],
#  ['ca', 'choose', 'seat', 'online', 'booked', 'smh'],
#  ['three', 'hour', 'flight', 'delay', 'phone', 'counting'],
#  ['shame',
#   'great',
#   'customer',
#   'service',
#   'continued',
#   'sfo',
#   'slightly',
#   'absurd'],
#  ['hard',
#   'younger',
#   'siblings',
#   'cousin',
#   'want',
#   'go',
#   'airplane',
#   'get',
#   'better'],
#  ['terminal',
#   'mia',
#   'food',
#   'open',
#   'esp',
#   'flights',
#   'two',
#   'hours',
#   'early',
#   'like',
#   'recommended',
#   'ca',
#   'eat'],
#  ['newarkliberty',
#   'airport',
#   'need',
#   'indicate',
#   'different',
#   'gate',
#   'terminals',
#   'flyingainteasy'],
#  ['dm',
#   'hold',
#   'customer',
#   'service',
#   'long',
#   'time',
#   'min',
#   'getting',
#   'run',
#   'around',
#   'thanks'],
#  ['cancelled',
#   'flightlation',
#   'days',
#   'due',
#   'weather',
#   'nashville',
#   'trips',
#   'airport',
#   'time',
#   'communicated',
#   'late',
#   'flight',
#   'sw'],
#  ['take',
#   'longer',
#   'get',
#   'gate',
#   'flight',
#   'takes',
#   'minutes',
#   'flying',
#   'time',
#   'minutes',
#   'runway',
#   'far'],
#  ['booked', 'us', 'airways', 'site', 'see', 'cancelled', 'flight', 'link'],
#  ['someone',
#   'actually',
#   'either',
#   'call',
#   'back',
#   'help',
#   'figure',
#   'getting',
#   'home'],
#  ['free', 'wifi', 'flt', 'pbi', 'make', 'hr', 'delay', 'treat', 'us', 'right'],
#  ['seriously',
#   'hate',
#   'since',
#   'ca',
#   'accommodate',
#   'due',
#   'inclemental',
#   'weather',
#   'disruptions',
#   'lol',
#   'funny'],
#  ['open',
#   'credit',
#   'card',
#   'earn',
#   'miles',
#   'wo',
#   'nt',
#   'credit',
#   'miles',
#   'account',
#   'restore',
#   'forfeited',
#   'miles'],
#  ['hi',
#   'flight',
#   'confirmation',
#   'currently',
#   'stuck',
#   'norfolk',
#   'trying',
#   'get',
#   'lga',
#   'nyc',
#   'ant',
#   'updates',
#   'thx'],
#  ['worst',
#   'airline',
#   'world',
#   'crap',
#   'website',
#   'worthless',
#   'app',
#   'late',
#   'flight',
#   'flight',
#   'suck',
#   'shut'],
#  ['noting',
#   'perfectly',
#   'fine',
#   'attitude',
#   'dealings',
#   'flyers',
#   'stubborn',
#   'demanding',
#   'unwilling',
#   'accommodate'],
#  ['hold', 'hour', 'cool', 'guys'],
#  ['rubbish',
#   'social',
#   'media',
#   'air',
#   'two',
#   'hours',
#   'late',
#   'flight',
#   'better',
#   'cancelled',
#   'flightled'],
#  ['disgusting',
#   'chicken',
#   'entree',
#   'ever',
#   'seen',
#   'standards',
#   'seriously',
#   'nosedived',
#   'newamerican'],
#  ['someone', 'severe', 'anxiety', 'one', 'person', 'help', 'next'],
#  ['going', 'website', 'amp', 'mobile', 'app', 'help'],
#  ['yes', 'guys', 'get', 'act', 'together'],
#  ['honestly',
#   'shock',
#   'process',
#   'service',
#   'compares',
#   'airline',
#   'experiences',
#   'really',
#   'sure',
#   'say'],
#  ['thanks',
#   'trying',
#   'take',
#   'money',
#   'without',
#   'notice',
#   'industry',
#   'cancelled',
#   'flight',
#   'service',
#   'refund',
#   'issued',
#   'cont'],
#  ['finally',
#   'hung',
#   'hours',
#   'able',
#   'get',
#   'flight',
#   'needed',
#   'stuckintampa'],
#  ['late',
#   'flight',
#   'reflight',
#   'booking',
#   'problems',
#   'morning',
#   'already',
#   'longer',
#   'need',
#   'hotel',
#   'room'],
#  ['safety', 'might', 'priority', 'organization', 'clearly'],
#  ['hrs',
#   'hanging',
#   'oh',
#   'understand',
#   'things',
#   'get',
#   'crazy',
#   'n',
#   'sometimes',
#   'hours',
#   'long',
#   'enough'],
#  ['rude',
#   'gate',
#   'agent',
#   'wholly',
#   'unacceptable',
#   'us',
#   'amp',
#   'passengers',
#   'think',
#   'last',
#   'time',
#   'sw'],
#  ['bag', 'missing', 'landed', 'hours', 'ago', 'help'],
#  ['human',
#   'contact',
#   'mths',
#   'cust',
#   'relations',
#   'refund',
#   'dept',
#   'ever',
#   'problem',
#   'u',
#   'humans',
#   'talk'],
#  ['shits', 'got', 'ta', 'stop', 'rt', 'fleet', 'fleek'],
#  ['charged',
#   'one',
#   'way',
#   'others',
#   'leaving',
#   'pittsburgh',
#   'equipment',
#   'charged',
#   'hung'],
#  ['seriously',
#   'cats',
#   'dead',
#   'going',
#   'pissed',
#   'thankful',
#   'evil',
#   'wants',
#   'soul'],
#  ['letting', 'us', 'go', 'runway', 'mechanical', 'problems', 'wewantcomps'],
#  ['hold',
#   'hours',
#   'calling',
#   'since',
#   'monday',
#   'flight',
#   'today',
#   'need',
#   'help',
#   'worst',
#   'noexcusesaccepted'],
#  ['usairways',
#   'lost',
#   'passenger',
#   'today',
#   'upholding',
#   'promise',
#   'excellent',
#   'customer',
#   'service'],
#  ['never',
#   'bad',
#   'experience',
#   'one',
#   'took',
#   'cake',
#   'extortion',
#   'carry',
#   'items',
#   'well'],
#  ['year',
#   'customer',
#   'lost',
#   'inches',
#   'really',
#   'hurt',
#   'every',
#   'time',
#   'person',
#   'front',
#   'shifts',
#   'raps',
#   'knees'],
#  ['hold',
#   'hours',
#   'flight',
#   'tomorrow',
#   'really',
#   'expect',
#   'sleep',
#   'night',
#   'stay',
#   'hold'],
#  ['well',
#   'considering',
#   'every',
#   'agent',
#   'claimed',
#   'unable',
#   'help',
#   'everything',
#   'else',
#   'waste',
#   'time',
#   'hear',
#   'call',
#   'corp'],
#  ['got', 'paying', 'extra', 'sit', 'way', 'back', 'awesome', 'never'],
#  ['mean', 'might', 'care', 'sister', 'assaulted', 'one', 'flights'],
#  ['continually',
#   'play',
#   'according',
#   'federal',
#   'regulations',
#   'every',
#   'seconds',
#   'could',
#   'see',
#   'quicker',
#   'service'],
#  ['gold',
#   'dividends',
#   'member',
#   'ca',
#   'get',
#   'anyone',
#   'phone',
#   'handle',
#   'cancelled',
#   'flighted',
#   'american',
#   'flight',
#   'tonight'],
#  ['got',
#   'demoted',
#   'gold',
#   'cuz',
#   'hubby',
#   'got',
#   'pqd',
#   'tho',
#   'enuf',
#   'spent',
#   'angry'],
#  ['baggage',
#   'delivery',
#   'bwi',
#   'delayed',
#   'unnecessarily',
#   'chaotic',
#   'disappointing',
#   'long',
#   'trip',
#   'frequent',
#   'traveler'],
#  ['never',
#   'fly',
#   'went',
#   'vacation',
#   'week',
#   'lost',
#   'bags',
#   'ways',
#   'clothes',
#   'thankyou'],
#  ['poor', 'excuse', 'towards', 'front', 'plane', 'sandwiches', 'pay'],
#  ['waited',
#   'two',
#   'hours',
#   'phone',
#   'book',
#   'get',
#   'mi',
#   'family',
#   'member',
#   'ill',
#   'time',
#   'essence'],
#  ['twice', 'said', 'ca', 'dim', 'lights', 'first', 'flight'],
#  ['lots',
#   'reports',
#   'system',
#   'failures',
#   'delaying',
#   'flights',
#   'last',
#   'week',
#   'currently',
#   'sitting',
#   'tarmac',
#   'ogg',
#   'hour'],
#  ['updating', 'flight', 'status', 'delays'],
#  ['telling', 'cancelled', 'flighting', 'flight'],
#  ['sucks',
#   'passengers',
#   'leaving',
#   'plane',
#   'make',
#   'room',
#   'luggage',
#   'checking',
#   'luggage',
#   'getting',
#   'back',
#   'delayed',
#   'flights',
#   'city'],
#  ['bein',
#   'calling',
#   'jetblue',
#   'respond',
#   'leave',
#   'number',
#   'call',
#   'back',
#   'think',
#   'jetblue',
#   'loosing',
#   'customer'],
#  ['mean', 'vegas', 'allowed', 'original', 'flight'],
#  ['trying',
#   'get',
#   'emails',
#   'talking',
#   'business',
#   'people',
#   'expect',
#   'airline',
#   'wifi'],
#  ['aaaand',
#   'hours',
#   'late',
#   'flightr',
#   'wo',
#   'catching',
#   'flight',
#   'til',
#   'stuck',
#   'airport',
#   'snowstorm',
#   'hotel',
#   'patience'],
#  ['us',
#   'ground',
#   'power',
#   'shorts',
#   'third',
#   'time',
#   'weary',
#   'german',
#   'passenger',
#   'deplanes',
#   'makes',
#   'jealous',
#   'auf',
#   'wiedersehen'],
#  ['thanks',
#   'would',
#   'like',
#   'apology',
#   'full',
#   'refund',
#   'please',
#   'confirm',
#   'receive'],
#  ['better',
#   'hold',
#   'flight',
#   'tucson',
#   'landed',
#   'houston',
#   'hour',
#   'delay',
#   'minor',
#   'computer',
#   'problem'],
#  ['frankly',
#   'worse',
#   'customer',
#   'service',
#   'ever',
#   'problems',
#   'happen',
#   'deal',
#   'defines',
#   'company',
#   'never',
#   'united'],
#  ['sorry', 'hate', 'united', 'wo', 'get', 'see', 'family', 'thursday'],
#  ['arrival',
#   'delayed',
#   'nearly',
#   'yeah',
#   'entire',
#   'day',
#   'airport',
#   'idea',
#   'stress',
#   'less',
#   'vacation',
#   'fail'],
#  ['either',
#   'fine',
#   'however',
#   'plundering',
#   'hard',
#   'earned',
#   'dollars',
#   'fine'],
#  ['gif', 'game', 'strong'],
#  ['sure',
#   'business',
#   'go',
#   'else',
#   'airline',
#   'travel',
#   'name',
#   'kathryn',
#   'sotelo'],
#  ['cancelled',
#   'flight',
#   'flights',
#   'yesterday',
#   'rebook',
#   'middle',
#   'seat',
#   'acceptable',
#   'upgrade',
#   'emergency',
#   'row',
#   'would',
#   'help',
#   'nothappy'],
#  ['flight',
#   'cancelled',
#   'flightled',
#   'amp',
#   'chaos',
#   'abounds',
#   'good',
#   'humour',
#   'please',
#   'give',
#   'free',
#   'everything',
#   'appease'],
#  ['late', 'flight'],
#  ['landed', 'phl', 'row', 'window', 'cover', 'could', 'use', 'luv'],
#  ['traveling', 'around', 'world', 'end', 'year', 'numbers', 'good'],
#  ['epic', 'fail', 'jetway', 'mins', 'tarmac'],
#  ['think', 'guys', 'could', 'mess', 'things', 'never', 'flying'],
#  ['flight',
#   'cancelled',
#   'flightled',
#   'need',
#   'rebooked',
#   'ca',
#   'online',
#   'answering',
#   'calls',
#   'help'],
#  ['hire',
#   'pos',
#   'pilots',
#   'thanks',
#   'ruining',
#   'trip',
#   'allowing',
#   'see',
#   'buddy',
#   'turns',
#   'unitedsucksdick'],
#  ['sorry', 'unfollowing'],
#  ['rented',
#   'van',
#   'drove',
#   'miles',
#   'strangers',
#   'arrived',
#   'home',
#   'offers',
#   'help',
#   'aa'],
#  ['hold',
#   'hrs',
#   'cancelled',
#   'flighted',
#   'flt',
#   'phl',
#   'dfw',
#   'need',
#   'assistance'],
#  ['worst',
#   'experience',
#   'life',
#   'avoid',
#   'costs',
#   'lose',
#   'belongings',
#   'humanity',
#   'even',
#   'offer',
#   'compensation'],
#  ['changed',
#   'last',
#   'name',
#   'mileageplus',
#   'acct',
#   'site',
#   'hour',
#   'hold',
#   'days',
#   'amp',
#   'change',
#   'yet'],
#  ['obviously',
#   'see',
#   'agent',
#   'booked',
#   'us',
#   'tomorrow',
#   'morning',
#   'hotel',
#   'transportation',
#   'pregnantwithtwins',
#   'stranded',
#   'angry'],
#  ['yes',
#   'computer',
#   'would',
#   'allow',
#   'get',
#   'san',
#   'diego',
#   'quick',
#   'customer',
#   'service',
#   'help',
#   'says',
#   'ca',
#   'rebook'],
#  ['know',
#   'check',
#   'complaint',
#   'ticket',
#   'said',
#   'dinner',
#   'booked',
#   'changed',
#   'refreshments',
#   'refund'],
#  ['going', 'nothing', 'like', 'always'],
#  ['flight',
#   'already',
#   'think',
#   'airline',
#   'flight',
#   'attendants',
#   'actually',
#   'emphasize',
#   'vape',
#   'still',
#   'smoking'],
#  ['miserable',
#   'trip',
#   'lost',
#   'bag',
#   'sat',
#   'found',
#   'mon',
#   'lost',
#   'shipping',
#   'day',
#   'ground',
#   'tues',
#   'might',
#   'return',
#   'flight',
#   'home'],
#  ['first',
#   'lost',
#   'bags',
#   'cancelled',
#   'flight',
#   'flight',
#   'home',
#   'min',
#   'wait',
#   'talk',
#   'somebody',
#   'poorservice',
#   'notgoodenough'],
#  ['probably',
#   'least',
#   'satisfactory',
#   'airline',
#   'ever',
#   'never',
#   'fails',
#   'disappoint'],
#  ['tried',
#   'calling',
#   'times',
#   'past',
#   'days',
#   'keep',
#   'getting',
#   'told',
#   'call',
#   'back',
#   'someone',
#   'please',
#   'help'],
#  ['calling',
#   'hours',
#   'reschedule',
#   'flight',
#   'dfw',
#   'due',
#   'weather',
#   'wo',
#   'even',
#   'let',
#   'stay',
#   'hold'],
#  ['anyone',
#   'realize',
#   'banning',
#   'peanuts',
#   'flight',
#   'due',
#   'allergic',
#   'person',
#   'ignores',
#   'p',
#   'nut',
#   'oil',
#   'amp',
#   'dust',
#   'previous',
#   'flights'],
#  ['check',
#   'broken',
#   'tablet',
#   'see',
#   'attached',
#   'picture',
#   'media',
#   'filmcrew',
#   'nbc',
#   'cnn'],
#  ['site', 'help'],
#  ['respond',
#   'complaints',
#   'cultural',
#   'appropriation',
#   'spirit',
#   'airlines',
#   'fly',
#   'list'],
#  ['two',
#   'hours',
#   'hold',
#   'talk',
#   'agent',
#   'disconnects',
#   'trying',
#   'two',
#   'days',
#   'wtf',
#   'hire',
#   'csrs',
#   'u',
#   'make'],
#  ['flight',
#   'ha',
#   'one',
#   'employee',
#   'said',
#   'reassigned',
#   'another',
#   'said',
#   'left',
#   'want',
#   'warm',
#   'weather'],
#  ['advise', 'happening', 'departure', 'delays', 'clt'],
#  ['tarmac',
#   'yest',
#   'cancelled',
#   'flight',
#   'today',
#   'hr',
#   'delay',
#   'send',
#   'txt',
#   'email',
#   'jfk',
#   'closed',
#   'amp',
#   'saved',
#   'trip',
#   'sit'],
#  ['deal',
#   'flt',
#   'today',
#   'departure',
#   'keeps',
#   'changing',
#   'going',
#   'late',
#   'flight'],
#  ['care', 'keeping', 'customers', 'safe', 'least', 'care', 'sister'],
#  ['really',
#   'acceptable',
#   'informed',
#   'plane',
#   'wo',
#   'start',
#   'chartering',
#   'bus',
#   'take',
#   'passengers',
#   'jfk'],
#  ['well', 'aware', 'insufficient', 'info', 'options'],
#  ['cmh',
#   'gate',
#   'staff',
#   'disaster',
#   'overbooked',
#   'volunteers',
#   'boarding',
#   'min',
#   'late',
#   'flight',
#   'trying',
#   'figure',
#   'issue',
#   'bringbackrealstaff'],
#  ['supposed', 'carry', 'pittsburgh', 'coming', 'boston', 'carry'],
#  ['flight',
#   'dallas',
#   'cancelled',
#   'flightled',
#   'talked',
#   'reservations',
#   'agent',
#   'got',
#   'new',
#   'flight',
#   'received',
#   'email'],
#  ['guess', 'follow', 'order', 'send', 'dm', 'tried', 'wo', 'send'],
#  ['system',
#   'gave',
#   'seat',
#   'economy',
#   'econ',
#   'seat',
#   'give',
#   'plus',
#   'seat',
#   'away'],
#  ['report',
#   'filed',
#   'airport',
#   'police',
#   'february',
#   'police',
#   'case',
#   'number',
#   'required'],
#  ['promised',
#   'rooms',
#   'wednesday',
#   'hotel',
#   'charged',
#   'us',
#   'per',
#   'room',
#   'pink',
#   'paper',
#   'needed',
#   'white'],
#  ['tried',
#   'speaking',
#   'multiple',
#   'people',
#   'reservations',
#   'desk',
#   'min',
#   'hold',
#   'waivethefee',
#   'poorcustomerservice',
#   'neptune'],
#  ['trying',
#   'book',
#   'another',
#   'flight',
#   'apply',
#   'credits',
#   'another',
#   'flight',
#   'ca',
#   'find'],
#  ['check',
#   'online',
#   'states',
#   'status',
#   'closed',
#   'mean',
#   'yet',
#   'able',
#   'reach',
#   'live',
#   'person'],
#  ['pilots',
#   'plane',
#   'flight',
#   'says',
#   'still',
#   'time',
#   'ground',
#   'minutes',
#   'ago'],
#  ['absolute',
#   'terrible',
#   'service',
#   'schedule',
#   'minute',
#   'layover',
#   'let',
#   'someone',
#   'plane',
#   'door',
#   'closed'],
#  ['first', 'pilot', 'first', 'officer', 'galley', 'flight'],
#  ['reservation',
#   'system',
#   'wo',
#   'even',
#   'let',
#   'us',
#   'leave',
#   'phone',
#   'way',
#   'fix',
#   'rebooked',
#   'wrong',
#   'day'],
#  ['waiting',
#   'new',
#   'pilot',
#   'door',
#   'plane',
#   'broke',
#   'global',
#   'services',
#   'status',
#   'airline',
#   'unsafe',
#   'stunning'],
#  ['making',
#   'folks',
#   'run',
#   'gate',
#   'explanation',
#   'zero',
#   'carts',
#   'transfer',
#   'elderly',
#   'handicap',
#   'phl'],
#  ['resolution'],
#  ['pay',
#   'extra',
#   'space',
#   'forced',
#   'put',
#   'backpack',
#   'seat',
#   'bag',
#   'flight',
#   'unprofessional'],
#  ['heard',
#   'voucher',
#   'miles',
#   'credit',
#   'cancelled',
#   'flighting',
#   'international',
#   'flight',
#   'yesterday',
#   'get',
#   'email'],
#  ['ticket',
#   'counter',
#   'people',
#   'helping',
#   'want',
#   'charge',
#   'money',
#   'even',
#   'horrible',
#   'day'],
#  ['cancelled',
#   'flightled',
#   'flight',
#   'baggage',
#   'held',
#   'hostage',
#   'chl',
#   'communication'],
#  ['flights', 'hrl', 'limited', 'route'],
#  ['sincere',
#   'cancelled',
#   'flighted',
#   'flight',
#   'made',
#   'drive',
#   'hours',
#   'get',
#   'home'],
#  ['ah', 'grasshopper', 'twitterz', 'kung', 'fu', 'good', 'hire', 'geeks'],
#  ['recommend',
#   'upgrading',
#   'ivr',
#   'using',
#   'call',
#   'back',
#   'email',
#   'texting',
#   'know',
#   'caller'],
#  ['sure',
#   'happened',
#   'msp',
#   'yesterday',
#   'unhappy',
#   'bag',
#   'delayed',
#   'sat',
#   'msp',
#   'hrs',
#   'delivery'],
#  ['little', 'surprised', 'early', 'bird', 'got', 'den', 'kc', 'worst'],
#  ['passed',
#   'frustrated',
#   'hours',
#   'ago',
#   'asked',
#   'get',
#   'first',
#   'plane',
#   'sat',
#   'hour'],
#  ['expect', 'response', 'customer', 'relations'],
#  ['anything'],
#  ['lost',
#   'luggage',
#   'flight',
#   'yesterday',
#   'morning',
#   'miami',
#   'newyork',
#   'lga',
#   'response',
#   'luggage',
#   'hrs',
#   'ltr'],
#  ['please',
#   'allow',
#   'speak',
#   'someone',
#   'dialogue',
#   'would',
#   'solve',
#   'issue',
#   'better',
#   'faster',
#   'emailing'],
#  ['three',
#   'hours',
#   'hold',
#   'disconnected',
#   'conf',
#   'ebhset',
#   'need',
#   'home',
#   'sunday',
#   'interview'],
#  ['black', 'hole', 'phone', 'system'],
#  ['flight',
#   'cancelled',
#   'flightlations',
#   'one',
#   'due',
#   'weather',
#   'one',
#   'mechanical',
#   'paid',
#   'hotel',
#   'bag',
#   'held',
#   'transfer',
#   'voucher',
#   'compensation'],
#  ['people', 'phone', 'ca', 'see', 'difference', 'poor', 'process'],
#  ['call', 'window', 'seat'],
#  ['worse', 'jetbae', 'rt', 'fleet', 'fleek'],
#  ['going',
#   'nightmare',
#   'guys',
#   'yesterday',
#   'zero',
#   'response',
# ...
#   'desk',
#   'servicing',
#   'full',
#   'service',
#   'line',
#   'desks',
#   'servicing',
#   'priority',
#   'full',
#   'srvc',
#   'wait',
#   'minutes',
#   'customer',
#   'svc',
#   'fail'],
#  ['thought',
#   'worst',
#   'airline',
#   'nah',
#   'guys',
#   'far',
#   'worse',
#   'decent',
#   'airline'],
#  ['please',
#   'msg',
#   'customer',
#   'service',
#   'invoice',
#   'dry',
#   'cleaning',
#   'wo',
#   'able',
#   'take',
#   'wet',
#   'clothes',
#   'airport'],
#  ['issued',
#   'travel',
#   'advisory',
#   'charlotte',
#   'wednesday',
#   'night',
#   'thursday',
#   'inches',
#   'snow'],
#  ['issue',
#   'fact',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promises',
#   'confirm',
#   'bag',
#   'location'],
#  ['get', 'money', 'people', 'public', 'apology', 'president', 'jet', 'blue'],
#  ['sent',
#   'dm',
#   'last',
#   'week',
#   'suit',
#   'regarding',
#   'error',
#   'response',
#   'given',
#   'please',
#   'answer',
#   'dm',
#   'tell',
#   'send',
#   'suit'],
#  ['thanks',
#   'overflight',
#   'booking',
#   'problems',
#   'first',
#   'class',
#   'automatically',
#   'downgrading',
#   'upgrade',
#   'min',
#   'boarding',
#   'ffstatusdontmatter',
#   'thenewaa'],
#  ['late',
#   'flight',
#   'denver',
#   'late',
#   'flight',
#   'newark',
#   'let',
#   'even',
#   'get',
#   'disaster',
#   'checking',
#   'bags',
#   'unacceptable'],
#  ['missed',
#   'daughter',
#   'suppose',
#   'dpt',
#   'ord',
#   'dpted',
#   'week',
#   'average',
#   'day',
#   'average'],
#  ['certain',
#   'flights',
#   'clt',
#   'nyc',
#   'notion',
#   'ca',
#   'rebook',
#   'customers',
#   'hours',
#   'absurd'],
#  ['enough', 'stop', 'flying', 'jetblue'],
#  ['oh',
#   'look',
#   'delayed',
#   'flight',
#   'additional',
#   'half',
#   'hour',
#   'arriving',
#   'officially',
#   'five',
#   'hours',
#   'planned'],
#  ['come',
#   'crew',
#   'traveling',
#   'flight',
#   'gets',
#   'better',
#   'seat',
#   'get',
#   'stuck',
#   'checking',
#   'bag',
#   'crews',
#   'bag',
#   'got',
#   'flight'],
#  ['going',
#   'ua',
#   'outbound',
#   'flight',
#   'last',
#   'thurs',
#   'delayed',
#   'long',
#   'delay'],
#  ['coming', 'still', 'spoken', 'rep'],
#  ['atrocious', 'customer', 'service'],
#  ['absolute', 'worst', 'customer', 'service', 'trying', 'reach', 'phone'],
#  ['another',
#   'ride',
#   'sw',
#   'employee',
#   'printed',
#   'boarding',
#   'passes',
#   'deficiency',
#   'training',
#   'obviously'],
#  ['well', 'one', 'missed', 'mark', 'snit', 'minute', 'stepped', 'counter'],
#  ['tried',
#   'ringing',
#   'told',
#   'try',
#   'late',
#   'flightr',
#   'supposed',
#   'leaving',
#   'hour'],
#  ['delayed',
#   'flight',
#   'wilmington',
#   'made',
#   'miss',
#   'flight',
#   'charlotte',
#   'figure',
#   'take',
#   'arrive',
#   'time'],
#  ['three',
#   'delayed',
#   'flights',
#   'missed',
#   'connections',
#   'first',
#   'class',
#   'flights',
#   'get',
#   'compensation',
#   'losing',
#   'seats'],
#  ['flight',
#   'delayed',
#   'hours',
#   'reason',
#   'given',
#   'sure',
#   'love',
#   'flying',
#   'airline',
#   'whatajoke'],
#  ['guys',
#   'know',
#   'musicians',
#   'sensitive',
#   'safety',
#   'instruments',
#   'flying',
#   'good',
#   'reason'],
#  ['flight',
#   'delayed',
#   'hour',
#   'pilots',
#   'spend',
#   'hours',
#   'phone',
#   'get',
#   'ep',
#   'agent',
#   'phone'],
#  ['certainly'],
#  ['baggage',
#   'lost',
#   'last',
#   'night',
#   'call',
#   'us',
#   'airways',
#   'bags',
#   'nobody',
#   'answering',
#   'phone',
#   'badcustomersrvice',
#   'whereismybag'],
#  ['wanted',
#   'change',
#   'anytime',
#   'flight',
#   'leaving',
#   'phone',
#   'hold',
#   'phone',
#   'answers',
#   'says',
#   'sorry',
#   'dice'],
#  ['every',
#   'channel',
#   'supposed',
#   'watch',
#   'scandal',
#   'free',
#   'flyfi',
#   'sweet'],
#  ['every',
#   'city',
#   'nationwide',
#   'sale',
#   'fabulous',
#   'fares',
#   'nothing',
#   'buffalo',
#   'except',
#   'cities'],
#  ['ridiculous', 'hours', 'hold', 'rebook', 'cancelled', 'flightled', 'flight'],
#  ['hour',
#   'delay',
#   'sitting',
#   'plane',
#   'still',
#   'wanna',
#   'charge',
#   'beer',
#   'nah',
#   'good'],
#  ['ca',
#   'english',
#   'spanish',
#   'rep',
#   'call',
#   'locate',
#   'bag',
#   'resolve',
#   'issue'],
#  ['thanks',
#   'rude',
#   'customer',
#   'service',
#   'hour',
#   'delay',
#   'really',
#   'helped',
#   'timing',
#   'wise',
#   'afternoon',
#   'meetings',
#   'hello'],
#  ['leave',
#   'jaipur',
#   'tomorrow',
#   'back',
#   'dehli',
#   'delhi',
#   'one',
#   'night',
#   'need',
#   'use',
#   'abilities',
#   'make',
#   'magic'],
#  ['want', 'bag', 'flight'],
#  ['oh',
#   'yea',
#   'buddy',
#   'bring',
#   'special',
#   'friend',
#   'conversation',
#   'seem',
#   'nothing'],
#  ['want',
#   'whiny',
#   'accommodated',
#   'several',
#   'passengers',
#   'whose',
#   'earlier',
#   'flight',
#   'cancelled',
#   'flightled',
#   'flight',
#   'long'],
#  ['miss', 'continental', 'days'],
#  ['cool', 'customer', 'told', 'care', 'either', 'expected'],
#  ['treats',
#   'service',
#   'members',
#   'like',
#   'crap',
#   'never',
#   'flying',
#   'unitedairlines'],
#  ['buy',
#   'tix',
#   'days',
#   'flight',
#   'ca',
#   'transfer',
#   'tix',
#   'flawed',
#   'security',
#   'logic',
#   'flawed',
#   'customer',
#   'service'],
#  ['another', 'week', 'passed', 'hoped', 'would', 'response'],
#  ['sharing',
#   'public',
#   'fly',
#   'times',
#   'year',
#   'sitting',
#   'tarmac',
#   'fll',
#   'staff',
#   'worst',
#   'ever',
#   'met'],
#  ['customer',
#   'services',
#   'agent',
#   'jorge',
#   'orlando',
#   'international',
#   'rude',
#   'disrespectful',
#   'never',
#   'want',
#   'deal',
#   'bullshit',
#   'ever'],
#  ['two',
#   'broken',
#   'airplanes',
#   'two',
#   'days',
#   'late',
#   'flightr',
#   'stranded',
#   'funeral',
#   'missing',
#   'last',
#   'semester',
#   'college'],
#  ['call',
#   'customer',
#   'service',
#   'course',
#   'say',
#   'nothing',
#   'offer',
#   'transfer',
#   'disconnect',
#   'line'],
#  ['know', 'reservations', 'team', 'hr', 'callback', 'time'],
#  ['week',
#   'going',
#   'make',
#   'anything',
#   'put',
#   'ease',
#   'asking',
#   'fix',
#   'things'],
#  ['hold',
#   'minutes',
#   'lack',
#   'quality',
#   'service',
#   'nobody',
#   'cares',
#   'hate',
#   'shitty',
#   'airline'],
#  ['change', 'flights', 'hours', 'crazy', 'please', 'help'],
#  ['board', 'plane', 'knowing', 'maint', 'issue'],
#  ['bought',
#   'ticket',
#   'yesterday',
#   'received',
#   'confirmation',
#   'tried',
#   'check',
#   'said',
#   'paid',
#   'called'],
#  ['days',
#   'finally',
#   'got',
#   'automated',
#   'service',
#   'call',
#   'back',
#   'hung',
#   'beyond',
#   'ridicules',
#   'help'],
#  ['involuntarily',
#   'bumped',
#   'passenger',
#   'ca',
#   'guarantee',
#   'another',
#   'flight',
#   'three',
#   'days'],
#  ['iah',
#   'ewr',
#   'broken',
#   'entertainment',
#   'system',
#   'wifi',
#   'despite',
#   'info',
#   'app'],
#  ['inadequate', 'accident'],
#  ['typically',
#   'get',
#   'problem',
#   'fixed',
#   'crew',
#   'expires',
#   'delay',
#   'turns',
#   'cancelled',
#   'flight'],
#  ['easily', 'ridiculous', 'experience', 'trying', 'spend', 'money', 'company'],
#  ['running',
#   'one',
#   'flight',
#   'mins',
#   'next',
#   'flight',
#   'sat',
#   'plane',
#   'hour'],
#  ['hands', 'worst', 'airline', 'travel', 'really', 'really', 'fucking', 'bad'],
#  ['last',
#   'call',
#   'customer',
#   'service',
#   'agent',
#   'called',
#   'back',
#   'stuck',
#   'hold',
#   'air',
#   'canada',
#   'hope',
#   'booked',
#   'flight'],
#  ['learned',
#   'customer',
#   'service',
#   'sxm',
#   'works',
#   'airport',
#   'jetblue',
#   'need',
#   'supervisor',
#   'anything'],
#  ['q', 'thanks', 'wondering', 'ones', 'disguised', 'call'],
#  ['thank',
#   'blowing',
#   'vacation',
#   'could',
#   'get',
#   'anywhere',
#   'today',
#   'make',
#   'reservation',
#   'also',
#   'lost',
#   'bags',
#   'mine'],
#  ['fight',
#   'get',
#   'credit',
#   'value',
#   'bag',
#   'got',
#   'skytrax',
#   'jetblue',
#   'corpgreed',
#   'nevertakeno'],
#  ['stuck',
#   'iah',
#   'waiting',
#   'flight',
#   'honolulu',
#   'hours',
#   'due',
#   'maintenance',
#   'issues',
#   'could',
#   'gotten',
#   'new',
#   'plane',
#   'fail'],
#  ['oh',
#   'ok',
#   'good',
#   'looking',
#   'forward',
#   'escaping',
#   'cold',
#   'bit',
#   'thanks'],
#  ['continually',
#   'getting',
#   'put',
#   'hold',
#   'painfully',
#   'inexperienced',
#   'people',
#   'calling',
#   'platinum',
#   'desk'],
#  ['yep',
#   'filed',
#   'claim',
#   'heathrow',
#   'yesterday',
#   'promised',
#   'call',
#   'morning',
#   'update',
#   'got',
#   'nothing'],
#  ['pls', 'help', 'seriously', 'beyond', 'ridiculous'],
#  ['please', 'stop'],
#  ['hi',
#   'virgin',
#   'hold',
#   'minutes',
#   'earlier',
#   'flights',
#   'la',
#   'nyc',
#   'tonight',
#   'earlier'],
#  ['mind', 'fee', 'told', 'ca', 'change', 'name', 'ticket'],
#  ['earned', 'place', 'worst', 'airline', 'business'],
#  ['counting',
#   'please',
#   'let',
#   'delayed',
#   'needtocatchmynextflight',
#   'alreadyrebookedonce'],
#  ['transf',
#   'held',
#   'min',
#   'agent',
#   'answered',
#   'helped',
#   'time',
#   'got',
#   'person',
#   'fare',
#   'seen',
#   'gone',
#   'get',
#   'supv'],
#  ['woman',
#   'gets',
#   'plane',
#   'holds',
#   'seats',
#   'bulkhead',
#   'friends',
#   'c',
#   'boarding',
#   'passes',
#   'paid',
#   'earlybird',
#   'thx'],
#  ['reschedule',
#   'cancelled',
#   'flightled',
#   'flights',
#   'online',
#   'change',
#   'button',
#   'greyed'],
#  ['rapid',
#   'trip',
#   'plane',
#   'ticket',
#   'idaho',
#   'california',
#   'problems',
#   'would',
#   'wonderful'],
#  ['car',
#   'accident',
#   'way',
#   'airport',
#   'missed',
#   'flight',
#   'rno',
#   'dca',
#   'trying',
#   'resched',
#   'line',
#   'hr',
#   'wait'],
#  ['almost',
#   'entire',
#   'east',
#   'coast',
#   'flights',
#   'planes',
#   'taking',
#   'traveling',
#   'fine',
#   'need',
#   'get',
#   'nev',
#   'asap'],
#  ['aa',
#   'load',
#   'people',
#   'board',
#   'plane',
#   'long',
#   'day',
#   'first',
#   'unserviceable'],
#  ['hours',
#   'friend',
#   'rebook',
#   'trip',
#   'korea',
#   'cancelled',
#   'flightled',
#   'connecting',
#   'flight',
#   'chicago',
#   'idiotic'],
#  ['hours', 'hours', 'four', 'hours', 'like', 'joke'],
#  ['thank',
#   'reply',
#   'frustration',
#   'spending',
#   'upgrade',
#   'puts',
#   'wait',
#   'list'],
#  ['trying',
#   'speak',
#   'agent',
#   'whole',
#   'day',
#   'cancelled',
#   'flightled',
#   'flight'],
#  ['child',
#   'someone',
#   'issue',
#   'flying',
#   'prepares',
#   'ahead',
#   'time',
#   'reduce',
#   'distress',
#   'caused',
#   'planes'],
#  ['another',
#   'twist',
#   'plot',
#   'took',
#   'miami',
#   'return',
#   'due',
#   'unsecured',
#   'cargo',
#   'door',
#   'stressful',
#   'vacation',
#   'ever'],
#  ['made',
#   'flight',
#   'still',
#   'update',
#   'emails',
#   'landed',
#   'info',
#   'ever',
#   'sent',
#   'second',
#   'flight',
#   'losing',
#   'biz'],
#  ['need',
#   'change',
#   'ticket',
#   'res',
#   'ca',
#   'changed',
#   'online',
#   'also',
#   'ca',
#   'get',
#   'call',
#   'due',
#   'high',
#   'volume',
#   'u',
#   'help'],
#  ['poorservice',
#   'poorcommunication',
#   'waitingsince',
#   'bags',
#   'frm',
#   'flight',
#   'jetblue'],
#  ['made',
#   'cancelled',
#   'flight',
#   'car',
#   'reservation',
#   'came',
#   'money',
#   'reschedule',
#   'time',
#   'without',
#   'crew'],
#  ['characters', 'cover', 'reasons', 'afraid'],
#  ['half',
#   'hour',
#   'late',
#   'flight',
#   'leaving',
#   'dfw',
#   'attempt',
#   'explanation'],
#  ['delay',
#   'mechanical',
#   'issues',
#   'weekend',
#   'flights',
#   'ridiculous',
#   'tweet',
#   'long',
#   'delayed'],
#  ['sucks'],
#  ['also',
#   'reservations',
#   'team',
#   'fault',
#   'bad',
#   'top',
#   'decision',
#   'feel',
#   'bad',
#   'reservations',
#   'social',
#   'media',
#   'teams'],
#  ['flight',
#   'delayed',
#   'one',
#   'remembered',
#   'turn',
#   'heat',
#   'flight',
#   'leaving',
#   'ord',
#   'seriously'],
#  ['wo', 'site', 'let', 'book', 'tickets', 'nov', 'jfk', 'kin'],
#  ['late',
#   'flight',
#   'phoenix',
#   'gave',
#   'ticks',
#   'away',
#   'arrived',
#   'chicago',
#   'held',
#   'bags',
#   'hostage',
#   'chicago',
#   'rented',
#   'van',
#   'drove',
#   'toledo',
#   'hr',
#   'drive'],
#  ['provide',
#   'us',
#   'alternative',
#   'flight',
#   'hours',
#   'late',
#   'flightr',
#   'ruining',
#   'trip',
#   'cancelled',
#   'flightled',
#   'angry',
#   'problems',
#   'ruined'],
#  ['sadly', 'words', 'represent', 'company', 'actions', 'talk', 'cheap'],
#  ['lounge',
#   'tells',
#   'us',
#   'pillows',
#   'grandma',
#   'one',
#   'ladies',
#   'opens',
#   'closet',
#   'see',
#   'right',
#   'unitedlies'],
#  ['one', 'would', 'tell', 'coming', 'would', 'guess', 'changes', 'flights'],
#  ['trying',
#   'call',
#   'reservations',
#   'desk',
#   'past',
#   'hours',
#   'ca',
#   'get',
#   'expected'],
#  ['merging',
#   'american',
#   'negatively',
#   'affect',
#   'quality',
#   'integrity',
#   'longer',
#   'fly'],
#  ['ripped',
#   'suitcase',
#   'yelled',
#   'attitude',
#   'geraldine',
#   'employee',
#   'baggage',
#   'center',
#   'worst',
#   'jetblue'],
#  ['site', 'back'],
#  ['fair', 'set', 'payed', 'full', 'seat', 'get', 'access', 'full', 'seat'],
#  ['done',
#   'process',
#   'initiated',
#   'saturday',
#   'morning',
#   'ca',
#   'get',
#   'info',
#   'website',
#   'issues',
#   'amp',
#   'inadequate',
#   'phone',
#   'coverage',
#   'get',
#   'update'],
#  ['upset',
#   'luggage',
#   'damaged',
#   'rude',
#   'employee',
#   'laguardia',
#   'airport',
#   'help'],
#  ['quick',
#   'response',
#   'offering',
#   'assistance',
#   'lack',
#   'follow',
#   'really',
#   'service',
#   'expecting'],
#  ['delayed',
#   'baggage',
#   'claim',
#   'land',
#   'hopefully',
#   'bag',
#   'broken',
#   'damaged',
#   'lost',
#   'w',
#   'c',
#   'result',
#   'complaints'],
#  ['hi',
#   'got',
#   'message',
#   'part',
#   'flights',
#   'cancelled',
#   'flightled',
#   'ca',
#   'rebook',
#   'online',
#   'nobody',
#   'answers',
#   'phone',
#   'call',
#   'help'],
#  ['hour', 'wait', 'reflight', 'booking', 'problems', 'line', 'omaha'],
#  ['stay',
#   'chicago',
#   'overnight',
#   'meet',
#   'bags',
#   'hope',
#   'stay',
#   'put',
#   'get',
#   'put',
#   'flight'],
#  ['think', 'ever', 'us', 'airways', 'flight', 'went', 'smoothly'],
#  ['said', 'last', 'night', 'though'],
#  ['got',
#   'minutes',
#   'takeoff',
#   'time',
#   'anyone',
#   'wandered',
#   'address',
#   'line',
#   'people'],
#  ['aa',
#   'also',
#   'hour',
#   'late',
#   'flight',
#   'depart',
#   'ohare',
#   'luggage',
#   'happy',
#   'standing',
#   'long',
#   'line',
#   'baggage',
#   'svc'],
#  ['really',
#   'proactive',
#   'passengers',
#   'know',
#   'entertainment',
#   'system',
#   'working',
#   'least',
#   'let',
#   'get',
#   'mag'],
#  ['yep', 'certain', 'flight'],
#  ['yeah',
#   'told',
#   'would',
#   'next',
#   'flight',
#   'drove',
#   'nt',
#   'drove',
#   'second',
#   'time'],
#  ['zoom', 'sauce', 'potatoes', 'stuff', 'vile', 'mean', 'vile'],
#  ['anything',
#   'get',
#   'moving',
#   'almost',
#   'hrs',
#   'hundreds',
#   'jfk',
#   'upset',
#   'tired',
#   'want',
#   'get',
#   'ba'],
#  ['guys',
#   'give',
#   'helping',
#   'people',
#   'phone',
#   'tree',
#   'hangs',
#   'flight',
#   'tomorrow',
#   'connection',
#   'pending'],
#  ['going',
#   'flight',
#   'buffalo',
#   'jfk',
#   'figured',
#   'anything',
#   'temperature',
#   'tower',
#   'yet'],
#  ['united', 'flight', 'ever', 'time', 'americanisbetter'],
#  ['two',
#   'hours',
#   'ugh',
#   'get',
#   'vouchers',
#   'inexcusable',
#   'esp',
#   'pre',
#   'flight',
#   'check',
#   'ok'],
#  ['also', 'phone', 'customer', 'service', 'almost', 'useless'],
#  ['another',
#   'customer',
#   'non',
#   'service',
#   'waited',
#   'solve',
#   'problem',
#   'would',
#   'miss',
#   'funeral',
#   'suck'],
#  ['trying',
#   'call',
#   'book',
#   'reward',
#   'ticket',
#   'one',
#   'world',
#   'partners',
#   'automated',
#   'system',
#   'wo',
#   'nt',
#   'let',
#   'talk',
#   'great',
#   'job'],
#  ['absurd',
#   'waited',
#   'flight',
#   'attendant',
#   'assigned',
#   'flight',
#   'late',
#   'flight',
#   'nt',
#   'others'],
#  ['play',
#   'ear',
#   'know',
#   'best',
#   'buy',
#   'chewey',
#   'oatmeal',
#   'cookies',
#   'customer',
#   'care',
#   'folks'],
#  ['useless',
#   'response',
#   'need',
#   'functioning',
#   'wheelchair',
#   'customer',
#   'care',
#   'form',
#   'fill'],
#  ['checked',
#   'flight',
#   'sfo',
#   'lax',
#   'amp',
#   'told',
#   'atlantic',
#   'flying',
#   'club',
#   'gold',
#   'get',
#   'benefits'],
#  ['even', 'open', 'laptop', 'seat', 'paid', 'premium', 'let'],
#  ['filled',
#   'baggage',
#   'claim',
#   'phone',
#   'last',
#   'night',
#   'check',
#   'status',
#   'discover',
#   'rep',
#   'confused',
#   'arkansas',
#   'alaska'],
#  ['paid',
#   'extra',
#   'seat',
#   'amp',
#   'monitor',
#   'work',
#   'refund',
#   'seat',
#   'conf',
#   'mdbeei',
#   'mcmullen'],
#  ['one', 'flights', 'instead', 'lost', 'bags', 'add', 'insult', 'injury'],
#  ['weak', 'see', 'ya', 'hey'],
#  ['hope',
#   'thank',
#   'help',
#   'traveled',
#   'halfway',
#   'across',
#   'globe',
#   'wants',
#   'suitcase'],
#  ['twitter',
#   'cust',
#   'svc',
#   'rule',
#   'nt',
#   'say',
#   'fell',
#   'short',
#   'told',
#   'u',
#   'u',
#   'u',
#   'ca',
#   'nt',
#   'solve',
#   'problem',
#   'say',
#   'anything'],
#  ['mold', 'flight', 'filthyplane', 'hopeidonotgetsick'],
#  ['question',
#   'possible',
#   'book',
#   'seat',
#   'infant',
#   'giving',
#   'option',
#   'want',
#   'seat'],
#  ...]
